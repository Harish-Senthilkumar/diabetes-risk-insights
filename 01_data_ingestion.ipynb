# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-Senthilkumar/diabetes-risk-insights/blob/main/01_data_ingestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the official UCI package — this is a delivery service
# that goes and fetches the dataset directly from UCI's servers for me
# !pip install ucimlrepo

# Import the function I just installed so I can actually use it
from ucimlrepo import fetch_ucirepo

# Call the function with the dataset's ID number (891) to download it
# into a variable called 'cdc_diabetes' — think of this as unboxing
# the package the delivery service just brought us
cdc_diabetes = fetch_ucirepo(id=891)

# Look at the 'metadata' info that comes bundled with the dataset —
# like reading the label on a box before opening it
print(cdc_diabetes.metadata)
# Out:
# ...
# {'uci_id': 891, 'name': 'CDC Diabetes Health Indicators', 'repository_url': 'https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators', 'data_url': 'https://archive.ics.uci.edu/static/public/891/data.csv', 'abstract': 'The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy. ', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Tabular', 'Multivariate'], 'num_instances': 253680, 'num_features': 21, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Sex', 'Age', 'Education Level', 'Income'], 'target_col': ['Diabetes_binary'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'yea
# ...

# %%
#
from google.colab import userdata

# Retrieve the GitHub access token from Colab's Secrets manager rather than
# hardcoding it in the notebook. This keeps credentials out of version
# control -- a standard security practice when a repo may be public.
github_token = userdata.get('GITHUB_TOKEN')

# !git config --global user.email "harishsenthilkmr@gmail.com"
# !git config --global user.name "Harish-Senthilkumar"

# !git clone https://{github_token}@github.com/Harish-Senthilkumar/diabetes-risk-insights.git
# Out:
# Cloning into 'diabetes-risk-insights'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# Extract the input features table (every column except the diabetes
# outcome) from the dataset object returned by fetch_ucirepo.
X = cdc_diabetes.data.features

# Extract the target column -- whether or not each person has diabetes --
# which is what we'll eventually train a model to predict.
y = cdc_diabetes.data.targets

# Display the shape of the features table as (number of rows, number of
# columns), giving a first sense of the dataset's size.
print("Dataset shape:", X.shape)

# Preview the first 5 rows to see actual column names and sample values.
X.head()
# Out:
# Dataset shape: (253680, 21)
#    HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 0       1         1          1   40       1       0                     0
# 1       0         0          0   25       1       0                     0
# 2       1         1          1   28       0       0                     0
# 3       1         0          1   27       0       0                     0
# 4       1         1          1   24       0       0                     0
#
#    PhysActivity  Fruits  Veggies  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0             0       0        1  ...              1            0        5
# 1             1       0        0  ...              0            1        3
# 2             0       1        0  ...              1            1        5
# 3             1       1        1  ...              1            0        2
# 4             1       1        1  ...              1            0        2
#
# ...

# %%
#Importing panas -- the library for making the data look like excel and tabular.
#pd is the object type
import pandas as pd

#Confirm X is a standard pandas DataFrame, the industry-standard; structure for tabular data in python
print(type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>
